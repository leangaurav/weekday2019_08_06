# %% [markdown]
# - Read sheet "Australia by Residence" from Australia.xlsx
# - Ignore the first 20 rows.
# - List all Column and Row indexes(Print their names)
#
# Dataset Analysis
# - Describe the dataset
# - Use values and index attributes on both Row and Column Indexes
# - Check Shape, Datatypes and other attributes
# - Observe the datatype of each columns' data
#
#
# Drop
# - Delete all Data where the Type = "Emmigrants" or Type is not "Immigrants" (Row Deletion)
# - Find columns for which more than 50% data is missing and drop them (Column Deletion)
# - Drop Unnessary Columns: Type, Coverage, Area, Reg, Dev (Column deletion)
#     Your columns should now look like "OdName,AreaName,RegName,DevName,1980 ... 2008"
#
# Rename
# - Rename columns :OdName -> Country; RegName -> Region
# - Convert Column Names with Int type to Strings to avoid index errors with string indexing "1980, 1981 etc." => " '1980', '1981' ... " (Use rename)
# - Save the dataset to a new file AustraliaFiltered.csv
#
# Head Tail Sort
# - Find Total number of immigrants for all years, and create a new column Total in data Frame
# - Sort Data by the new column Total and analyze the fist few rows. (get first few rows using head)
#     - find something weird in the dataset ? Delete that row 'world'
# - Analyze last few rows also in the sorted result (Don't sort inplace)
#
# - Check if these have all unique values or not:
#     - countries
#     - continents
#     - country continent pairs
#
#
# - Find countries for which no of immigrants for all years is 0
# - Find count of above countries
# - Find countries for which no of immigrants is 0 for any year

# %%
import pandas as pd

# %%
df1 = pd.read_excel(r'C:\Users\Dell\Desktop\weekday2019_08_06\Assignments\Australia.xlsx',sheet_name = 'Australia by Residence',skiprows = 20)

# %%
dfObj = pd.DataFrame(df1, columns= ['Type','Coverage','OdName','AreaName','RegName','DevName'])

# %%
print(df1.describe(include = 'all'))
# Out:
#              Type Coverage OdName        AREA AreaName          REG  \
# count         448      448    448  448.000000      448   448.000000
# unique          2        1    224         NaN        7          NaN
# top     Emigrants     Both  Benin         NaN   Africa          NaN
# freq          224      448      2         NaN      112          NaN
# mean          NaN      NaN    NaN  912.955357      NaN  1208.040179
# std           NaN      NaN    NaN   15.019682      NaN  1109.669573
# min           NaN      NaN    NaN  903.000000      NaN   905.000000
# 25%           NaN      NaN    NaN  903.750000      NaN   914.000000
# 50%           NaN      NaN    NaN  908.000000      NaN   922.000000
# 75%           NaN      NaN    NaN  909.000000      NaN   926.000000
# max           NaN      NaN    NaN  999.000000      NaN  5501.000000
#
#           RegName         DEV             DevName           1980  ...  \
# count         448  448.000000                 448     448.000000  ...
# ...

# %%
print(df1.columns)
print(df1.shape)
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')
# (448, 43)

# %%
print(df1.dtypes)
# Out:
# Type        object
# Coverage    object
# OdName      object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009        object
# 2010        object
# 2011        object
# 2012        object
# 2013        object
# dtype: object

# %%
print(df1.columns.values[2])
print(df1.index.values[2])
# Out:
# OdName
# 2

# %%
df1 =df1.drop(df1[df1.Type != 'Immigrants'].index)

# %%
thresh = len(df1) * 0.5
print(df1.dropna(thresh = thresh, axis =1,inplace = True))
# Out:
# None

# %%
#Type, Coverage, Area, Reg, Dev
df1.drop(['Type','Coverage','AREA','REG','DEV'],axis=1,inplace = True)

# %%
df1 = df1.rename(columns = {"OdName":"Country","RegName":"Region"})
print(df1.columns)
# Out:
# Index([ 'Country', 'AreaName',   'Region',  'DevName',       1980,       1981,
#              1982,       1983,       1984,       1985,       1986,       1987,
#              1988,       1989,       1990,       1991,       1992,       1993,
#              1994,       1995,       1996,       1997,       1998,       1999,
#              2000,       2001,       2002,       2003,       2004,       2005,
#              2006,       2007,       2008,       2009,       2010,       2011,
#              2012,       2013],
#       dtype='object')

# %%
df1.columns.map(type)
# Out:
# Index([<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>, <class 'int'>, <class 'int'>,
#        <class 'int'>, <class 'int'>],
#       dtype='object')

# %%
df1.rename(columns = lambda x: str(x), inplace=True)
#df1.columns = df1.columns.astype(str)-- this also can work
df1.columns.map(type)
# Out:
# Index([<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>],
#       dtype='object')

# %%
df1.to_csv('Australia_filtered.csv')

# %%
total = df1.count(axis='columns')
df1["Total"] = total
print(df1.columns)
# Out:
# Index(['Country', 'AreaName', 'Region', 'DevName', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %%
df1
# Out:
#                                                Country  \
# 224                                        Afghanistan
# 225                                            Albania
# 226                                            Algeria
# 227                                     American Samoa
# 228                                            Andorra
# 229                                             Angola
# 230                                           Anguilla
# 231                                Antigua and Barbuda
# 232                                          Argentina
# 233                                            Armenia
# 234                                              Aruba
# 235                                          Australia
# 236                                            Austria
# 237                                         Azerbaijan
# 238                                            Bahamas
# 239                                            Bahrain
# ...

# %%
res1 = df1.sort_values(by = ['Total'], ascending = False)
print(res1.head(5))
print(res1.tail(5))
# Out:
#            Country                         AreaName  \
# 224    Afghanistan                             Asia
# 225        Albania                           Europe
# 366  New Caledonia                          Oceania
# 367    New Zealand                          Oceania
# 368      Nicaragua  Latin America and the Caribbean
#
#                         Region             DevName   1980   1981   1982  \
# 224              Southern Asia  Developing regions     10     20     30
# 225            Southern Europe   Developed regions      0      0      0
# 366                  Melanesia  Developing regions    160    150    210
# 367  Australia and New Zealand   Developed regions  34370  34440  23920
# 368            Central America  Developing regions      0      0      0
#
#       1983   1984   1985  ...   2005   2006   2007   2008  2009  2010  2011  \
# 224     30     70    100  ...    110    180    140    560    ..    ..    ..
# ...

# %%
#print(df1.Country.is_unique())
print(df1['Country'].is_unique)
print(df1.Country.value_counts())
# Out:
# True
# Benin                                             1
# Costa Rica                                        1
# Belize                                            1
# Micronesia (Federated States of)                  1
# Slovenia                                          1
# Qatar                                             1
# Honduras                                          1
# Bosnia and Herzegovina                            1
# Tajikistan                                        1
# Georgia                                           1
# Lithuania                                         1
# Netherlands                                       1
# Canada                                            1
# Bulgaria                                          1
# Azerbaijan                                        1
# Kazakhstan                                        1
# Guyana                                            1
# Tonga                                             1
# ...

# %%
print(df1['AreaName'].is_unique)
print(df1.AreaName.value_counts())
# Out:
# False
# Africa                             56
# Asia                               51
# Latin America and the Caribbean    45
# Europe                             43
# Oceania                            23
# Northern America                    4
# World                               2
# Name: AreaName, dtype: int64

# %%
df1.groupby(['Country','AreaName']).size()
# Out:
# Country                                               AreaName
# Afghanistan                                           Asia                               1
# Albania                                               Europe                             1
# Algeria                                               Africa                             1
# American Samoa                                        Oceania                            1
# Andorra                                               Europe                             1
# Angola                                                Africa                             1
# Anguilla                                              Latin America and the Caribbean    1
# Antigua and Barbuda                                   Latin America and the Caribbean    1
# Argentina                                             Latin America and the Caribbean    1
# Armenia                                               Asia                               1
# ...

# %%
#b = df1.groupby(by = ['Country'])['Total'].eq(0)

df1.groupby(['Total']).apply(lambda x: len(set(x)) == 0).all()
# Out:
# False

# %%
df1.groupby(['Total']).apply(lambda x: len(set(x)) == 0).any()
# Out:
# False
